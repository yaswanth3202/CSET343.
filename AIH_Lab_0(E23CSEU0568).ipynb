# %%
## write data in a file

file = open("/content/drive/MyDrive/Colab Notebooks/K Yaswanth Kumar.txt","w");
file.write("Name: K Yaswanth Kumar\n")
file.write("Roll Number: 568\n")

file.close()
print("Data written successfully.")
# Out:
# Data written successfully.

# %%
# Reading data from a file

file = open("/content/drive/MyDrive/Colab Notebooks/K Yaswanth Kumar.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Name: K Yaswanth Kumar
# Roll Number: 568

# %%
# Pandas is a Python library mainly used for working with tabular data
# such as Excel sheets, CSV files, and database-like tables.
import pandas as pd

# Creating data
data = {
    "Name": ["yashh", "Vinith", "Khushal", "Raja"],
    "Age": [19, 21, 20, 21],
    "Marks": [72, 92, 95, 89]
}

# Creating DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age  Marks
# 0    yashh   19     72
# 1   Vinith   21     92
# 2  Khushal   20     95
# 3     Raja   21     89

# %%
df.to_csv("students.csv", index=False)

# %%
print(df[["Name","Marks"]])
# Out:
#       Name  Marks
# 0    yashh     72
# 1   Vinith     92
# 2  Khushal     95
# 3     Raja     89

# %%
avr = df["Marks"].mean()

print("average Marks:",avr)
# Out:
# average Marks: 87.0

# %%
print("Highest Marks:", df["Marks"].max())
# Out:
# Highest Marks: 95

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df)
# Out:
#       Name  Age  Marks
# 0    yashh   19     72
# 1   Vinith   21     92
# 2  Khushal   20     95
# 3     Raja   21     89

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
# Out:
# [10 20 30 40 50]

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print("Addition:", numbers + 5)
print("Subtraction:", numbers - 5)
print("Multiplication:", numbers * 2)
print("Division:", numbers / 2)
# Out:
# Addition: [15 25 35 45 55]
# Subtraction: [ 5 15 25 35 45]
# Multiplication: [ 20  40  60  80 100]
# Division: [ 5. 10. 15. 20. 25.]

# %%
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [65, 72, 78, 85, 90]

plt.plot(tests, marks)

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [65, 72, 78, 85, 90]

plt.plot(tests, marks, marker="o")

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

students = ["Sai Teja", "Vinith", "Khushal", "Raja"]
marks = [82, 95, 92, 89]

plt.bar(students, marks)

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

languages = ["Python", "Java", "C#", "C"]
students = [40, 30, 20, 10]

plt.pie(students, labels=languages, autopct="%1.1f%%")

plt.title("Programming Language Preference")

plt.show()

# %%
import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5, 6]
marks = [45, 50, 60, 68, 78, 90]

plt.scatter(study_hours, marks)

plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()
